# %%
# Data wrangling project on Volcanic Eruptions
import pandas as pd
import numpy as np

# %%
vol=pd.read_csv('eruptions.csv')

# %%
vol
# Out:
#        volcano_number            volcano_name  eruption_number  vei  \
# 0              266030                 Soputan            22354  NaN
# 1              343100              San Miguel            22355  NaN
# 2              233020  Fournaise, Piton de la            22343  NaN
# 3              345020      Rincon de la Vieja            22346  NaN
# 4              353010              Fernandina            22347  NaN
# ...               ...                     ...              ...  ...
# 11173          324020     Craters of the Moon            21101  0.0
# 11174          222161            Igwisi Hills            22141  1.0
# 11175          357121            Quetrupillan            22351  3.0
# 11176          357121            Quetrupillan            22352  3.0
# 11177          390090                Saunders            21099  0.0
#
#        start_year  start_month  start_day     evidence_method_dating  \
# 0          2020.0          3.0       23.0    Historical Observations
# ...

# %%
vol.shape
# Out:
# (11178, 13)

# %%
vol.head()
# Out:
#    volcano_number            volcano_name  eruption_number  \
# 0          266030                 Soputan            22354
# 1          343100              San Miguel            22355
# 2          233020  Fournaise, Piton de la            22343
# 3          345020      Rincon de la Vieja            22346
# 4          353010              Fernandina            22347
#
#     eruption_category area_of_activity  vei  start_year  start_month  \
# 0  Confirmed Eruption              NaN  NaN      2020.0          3.0
# 1  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 2  Confirmed Eruption              NaN  NaN      2020.0          2.0
# 3  Confirmed Eruption              NaN  NaN      2020.0          1.0
# 4  Confirmed Eruption              NaN  NaN      2020.0          1.0
#
#    start_day   evidence_method_dating  end_year  end_month  end_day  latitude  \
# 0       23.0  Historical Observations    2020.0        4.0      2.0     1.112
# ...

# %%
vol.tail()
# Out:
#        volcano_number         volcano_name  eruption_number  \
# 11173          324020  Craters of the Moon            21101
# 11174          222161         Igwisi Hills            22141
# 11175          357121         Quetrupillan            22351
# 11176          357121         Quetrupillan            22352
# 11177          390090             Saunders            21099
#
#         eruption_category area_of_activity  vei  start_year  start_month  \
# 11173  Confirmed Eruption      Sunset cone  0.0    -10060.0          NaN
# 11174  Confirmed Eruption       NE Volcano  1.0    -10450.0          NaN
# 11175  Confirmed Eruption              NaN  3.0    -10658.0          NaN
# 11176  Confirmed Eruption              NaN  3.0    -11345.0          NaN
# 11177  Confirmed Eruption              NaN  0.0         NaN          NaN
#
#        start_day     evidence_method_dating  end_year  end_month  end_day  \
# 11173        NaN  Radiocarbon (uncorrected)       NaN        NaN      NaN
# ...

# %%
vol.drop('eruption_category',axis=1,inplace=True)

# %%
vol.drop('area_of_activity',axis=1,inplace=True)

# %%
vol
# Out:
#        volcano_number            volcano_name  eruption_number  vei  \
# 0              266030                 Soputan            22354  NaN
# 1              343100              San Miguel            22355  NaN
# 2              233020  Fournaise, Piton de la            22343  NaN
# 3              345020      Rincon de la Vieja            22346  NaN
# 4              353010              Fernandina            22347  NaN
# ...               ...                     ...              ...  ...
# 11173          324020     Craters of the Moon            21101  0.0
# 11174          222161            Igwisi Hills            22141  1.0
# 11175          357121            Quetrupillan            22351  3.0
# 11176          357121            Quetrupillan            22352  3.0
# 11177          390090                Saunders            21099  0.0
#
#        start_year  start_month  start_day     evidence_method_dating  \
# 0          2020.0          3.0       23.0    Historical Observations
# ...

# %%
vol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11178 entries, 0 to 11177
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   volcano_number          11178 non-null  int64
#  1   volcano_name            11178 non-null  object
#  2   eruption_number         11178 non-null  int64
#  3   vei                     8272 non-null   float64
#  4   start_year              11177 non-null  float64
#  5   start_month             10985 non-null  float64
#  6   start_day               10982 non-null  float64
#  7   evidence_method_dating  9898 non-null   object
#  8   end_year                4332 non-null   float64
#  9   end_month               4329 non-null   float64
#  10  end_day                 4326 non-null   float64
#  11  latitude                11178 non-null  float64
#  12  longitude               11178 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
#create three dataframe
vol1=vol[vol['start_year']<=2000]
vol2=vol[vol['start_year']==2014]
vol3=vol[vol['start_year']>=2019]

# %%
vol1.head()
# Out:
#      volcano_number     volcano_name  eruption_number  vei  start_year  \
# 794          261030      Peuet Sague            15395  2.0      2000.0
# 795          282030     Suwanosejima            16946  3.0      2000.0
# 796          263310  Tengger Caldera            16062  2.0      2000.0
# 797          284080       Sumisujima            18352  0.0      2000.0
# 798          284110        Kita-Ioto            18391  0.0      2000.0
#
#      start_month  start_day   evidence_method_dating  end_year  end_month  \
# 794         12.0       25.0  Historical Observations    2000.0       12.0
# 795         12.0       19.0  Historical Observations    2004.0        7.0
# 796         11.0       29.0  Historical Observations    2001.0        1.0
# 797         10.0       30.0                      NaN    2000.0       10.0
# 798         10.0       30.0                      NaN    2000.0       10.0
#
#      end_day  latitude  longitude
# 794     26.0     4.903     96.289
# ...

# %%
vol2.head()
# Out:
#      volcano_number               volcano_name  eruption_number  vei  \
# 185          243040  Hunga Tonga-Hunga Ha'apai            20983  2.0
# 186          268060                   Gamalama            20989  2.0
# 187          290290                    Sinarka            20980  1.0
# 188          357120                 Villarrica            20996  1.0
# 189          257050                     Lopevi            20986  NaN
#
#      start_year  start_month  start_day   evidence_method_dating  end_year  \
# 185      2014.0         12.0       19.0  Historical Observations    2015.0
# 186      2014.0         12.0       18.0  Historical Observations    2014.0
# 187      2014.0         12.0        3.0  Historical Observations    2014.0
# 188      2014.0         12.0        2.0  Historical Observations    2020.0
# 189      2014.0         12.0        1.0  Historical Observations    2014.0
#
#      end_month  end_day  latitude  longitude
# 185        1.0     23.0   -20.536   -175.382
# ...

# %%
vol3.head()
# Out:
#    volcano_number            volcano_name  eruption_number  vei  start_year  \
# 0          266030                 Soputan            22354  NaN      2020.0
# 1          343100              San Miguel            22355  NaN      2020.0
# 2          233020  Fournaise, Piton de la            22343  NaN      2020.0
# 3          345020      Rincon de la Vieja            22346  NaN      2020.0
# 4          353010              Fernandina            22347  NaN      2020.0
#
#    start_month  start_day   evidence_method_dating  end_year  end_month  \
# 0          3.0       23.0  Historical Observations    2020.0        4.0
# 1          2.0       22.0  Historical Observations    2020.0        2.0
# 2          2.0       10.0  Historical Observations    2020.0        4.0
# 3          1.0       31.0  Historical Observations    2020.0        4.0
# 4          1.0       12.0  Historical Observations    2020.0        1.0
#
#    end_day  latitude  longitude
# 0      2.0     1.112    124.737
# ...

# %%
vol.shape,vol2.shape,vol3.shape
# Out:
# ((11178, 13), (44, 13), (36, 13))

# %%
#Concatenate along a particular axis
sample_data=pd.concat([vol1,vol2],axis=1)

# %%
sample_data
# Out:
#      volcano_number     volcano_name  eruption_number  vei  start_year  \
# 794        261030.0      Peuet Sague          15395.0  2.0      2000.0
# 795        282030.0     Suwanosejima          16946.0  3.0      2000.0
# 796        263310.0  Tengger Caldera          16062.0  2.0      2000.0
# 797        284080.0       Sumisujima          18352.0  0.0      2000.0
# 798        284110.0        Kita-Ioto          18391.0  0.0      2000.0
# ..              ...              ...              ...  ...         ...
# 224             NaN              NaN              NaN  NaN         NaN
# 225             NaN              NaN              NaN  NaN         NaN
# 226             NaN              NaN              NaN  NaN         NaN
# 227             NaN              NaN              NaN  NaN         NaN
# 228             NaN              NaN              NaN  NaN         NaN
#
#      start_month  start_day   evidence_method_dating  end_year  end_month  \
# ...

# %%
sample_data.tail()
# Out:
#      volcano_number volcano_name  eruption_number  vei  start_year  \
# 224             NaN          NaN              NaN  NaN         NaN
# 225             NaN          NaN              NaN  NaN         NaN
# 226             NaN          NaN              NaN  NaN         NaN
# 227             NaN          NaN              NaN  NaN         NaN
# 228             NaN          NaN              NaN  NaN         NaN
#
#      start_month  start_day evidence_method_dating  end_year  end_month  ...  \
# 224          NaN        NaN                    NaN       NaN        NaN  ...
# 225          NaN        NaN                    NaN       NaN        NaN  ...
# 226          NaN        NaN                    NaN       NaN        NaN  ...
# 227          NaN        NaN                    NaN       NaN        NaN  ...
# 228          NaN        NaN                    NaN       NaN        NaN  ...
#
#      vei  start_year  start_month  start_day   evidence_method_dating  \
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10427 entries, 794 to 228
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   volcano_number          10383 non-null  float64
#  1   volcano_name            10383 non-null  object
#  2   eruption_number         10383 non-null  float64
#  3   vei                     7525 non-null   float64
#  4   start_year              10383 non-null  float64
#  5   start_month             10191 non-null  float64
#  6   start_day               10188 non-null  float64
#  7   evidence_method_dating  9159 non-null   object
#  8   end_year                3569 non-null   float64
#  9   end_month               3566 non-null   float64
#  10  end_day                 3563 non-null   float64
#  11  latitude                10383 non-null  float64
#  12  longitude               10383 non-null  float64
#  13  volcano_number          44 non-null     float64
# ...

# %%
sample_data.columns
# Out:
# Index(['volcano_number', 'volcano_name', 'eruption_number', 'vei',
#        'start_year', 'start_month', 'start_day', 'evidence_method_dating',
#        'end_year', 'end_month', 'end_day', 'latitude', 'longitude',
#        'volcano_number', 'volcano_name', 'eruption_number', 'vei',
#        'start_year', 'start_month', 'start_day', 'evidence_method_dating',
#        'end_year', 'end_month', 'end_day', 'latitude', 'longitude'],
#       dtype='object')

# %%
#create a dataframe of volcanic eruptions in year
